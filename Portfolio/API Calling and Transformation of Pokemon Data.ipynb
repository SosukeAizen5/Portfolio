# %% [markdown]
# # API Calling and Transformation of Pokemon Data
#
# ## David Berberena
#
# ## 5/19/2024

# %%
# To work with APIs, I need to import the requests library, which allows the user to connect to the API through Python. To 
# convert the API data into a DataFrame and subsequently transform that data, I will be importing pandas as well. 

import requests
import pandas as pd

# As I have worked with APIs before, I know that to request a large amount of information it is easiest to create a function
# that parses the API data and stores the specific values I wish to capture in variables. This function will capture the
# most important and pertinent Pokémon data needed for my dataset, which is the PokéDex number (id), Pokémon name (name), HP
# stat (base_stat in the hp stat dictionary), Attack stat (base_stat in the attack stat dictionary), Defense stat 
# (base_stat in the defense stat dictionary), Special Attack stat (base_stat in the special-attack stat dictionary), Special
# Defense stat (base_stat in the special-defense stat dictionary), Speed stat (base_stat in the speed stat dictionary), and 
# the Pokémon type (name in the type dictionary within the types list). Now as I have demonstrated and shown before in a 
# previous milestone, many Pokémon have two types, a primary and a secondary type. I have crafted the function to parse each
# type from the types list within the API data. 

# I have created the function to take the PokéDex number as a parameter so the API can be called for each Pokémon. As it 
# stands today, there are 1025 Pokémon, so that means this function will need to be run that many times. The API URL is also
# amended to a f-string statement so that the function can take whatever number is input for the pokemon_id parameter. 

def api_pokemon_data(pokemon_id):
    api_url = f'https://pokeapi.co/api/v2/pokemon/{pokemon_id}/'
    response = requests.get(api_url)
    
# With the request library used above to perform the GET request needed to access the API data from the URL, the below if 
# statement checks the status code and immediately converts the GET request's response into JSON format.
    
    if response.status_code == 200:
        data = response.json()
        
# After reviewing the API documentation and seeing that the primary and secondary types were hidden within a slot 1 and slot
# 2 designation, so I simply decided to parse the names of each type based on the number of type names within the types list
# seen in the JSON data structure using if-else statements. 
        
        types = data['types']
        primary_type = types[0]['type']['name'] if len(types) > 0 else None
        secondary_type = types[1]['type']['name'] if len(types) > 1 else None
        
# The elements of my dataset needed from the API data are turned into a dictionary in the block of code I have crafted below
# with the keys being the elements needed and the values being the observations extracted from within the API data. I have 
# used the next() function to have the function understand that the next value needed is the next base_stat in the JSON data
# structure since there are multiple base_stat values. The if statements are also placed here for extra security to ensure 
# the function grabs the right value. The primary and secondary type variables I have made above are also included here. 

        pokemon_info = {
            'id': data['id'],
            'name': data['name'],
            'hp': next(stat['base_stat'] for stat in data['stats'] if stat['stat']['name'] == 'hp'),
            'attack': next(stat['base_stat'] for stat in data['stats'] if stat['stat']['name'] == 'attack'),
            'defense': next(stat['base_stat'] for stat in data['stats'] if stat['stat']['name'] == 'defense'),
            'special_attack': next(stat['base_stat'] for stat in data['stats'] if stat['stat']['name'] == 'special-attack'),
            'special_defense': next(stat['base_stat'] for stat in data['stats'] if stat['stat']['name'] == 'special-defense'),
            'speed': next(stat['base_stat'] for stat in data['stats'] if stat['stat']['name'] == 'speed'),
            'primary_type': primary_type,
            'secondary_type': secondary_type
        }
        return pokemon_info
    

# To implement this function the number of times equal to the number of Pokémon, I have created a for loop that takes each 
# number in the range of the number of Pokémon available (1025) and uses it as an argument for the API call function to 
# extract the statistics needed for that Pokémon, and appends the results to an empty list until all Pokémon API calls have 
# been made. To verify that each Pokémon's data has been parsed successfully, I have made a print statement stating this. 

all_pokemon_data = []

for pokemon_id in range(1, 1026):
    pokemon_data = api_pokemon_data(pokemon_id)
    if pokemon_data:
        all_pokemon_data.append(pokemon_data)
    print(f"Parsed Pokémon with PokéDex Number {pokemon_id}")
    
# The list of Pokémon statistics can now be converted into a DataFrame now using the pd.DataFrame() from pandas.

all_pokemon = pd.DataFrame(all_pokemon_data)
# Out:
# Parsed Pokémon with PokéDex Number 1
# Parsed Pokémon with PokéDex Number 2
# Parsed Pokémon with PokéDex Number 3
# Parsed Pokémon with PokéDex Number 4
# Parsed Pokémon with PokéDex Number 5
# Parsed Pokémon with PokéDex Number 6
# Parsed Pokémon with PokéDex Number 7
# Parsed Pokémon with PokéDex Number 8
# Parsed Pokémon with PokéDex Number 9
# Parsed Pokémon with PokéDex Number 10
# Parsed Pokémon with PokéDex Number 11
# Parsed Pokémon with PokéDex Number 12
# Parsed Pokémon with PokéDex Number 13
# Parsed Pokémon with PokéDex Number 14
# Parsed Pokémon with PokéDex Number 15
# Parsed Pokémon with PokéDex Number 16
# Parsed Pokémon with PokéDex Number 17
# Parsed Pokémon with PokéDex Number 18
# Parsed Pokémon with PokéDex Number 19
# Parsed Pokémon with PokéDex Number 20
# Parsed Pokémon with PokéDex Number 21
# Parsed Pokémon with PokéDex Number 22
# Parsed Pokémon with PokéDex Number 23
# Parsed Pokémon with PokéDex Number 24
# Parsed Pokémon with PokéDex Number 25
# Parsed Pokémon with PokéDex Number 26
# Parsed Pokémon with PokéDex Number 27
# Parsed Pokémon with PokéDex Number 28
# Parsed Pokémon with PokéDex Number 29
# Parsed Pokémon with PokéDex Number 30
# Parsed Pokémon with PokéDex Number 31
# Parsed Pokémon with PokéDex Number 32
# Parsed Pokémon with PokéDex Number 33
# Parsed Pokémon with PokéDex Number 34
# Parsed Pokémon with PokéDex Number 35
# Parsed Pokémon with PokéDex Number 36
# Parsed Pokémon with PokéDex Number 37
# Parsed Pokémon with PokéDex Number 38
# Parsed Pokémon with PokéDex Number 39
# Parsed Pokémon with PokéDex Number 40
# Parsed Pokémon with PokéDex Number 41
# Parsed Pokémon with PokéDex Number 42
# Parsed Pokémon with PokéDex Number 43
# Parsed Pokémon with PokéDex Number 44
# Parsed Pokémon with PokéDex Number 45
# Parsed Pokémon with PokéDex Number 46
# Parsed Pokémon with PokéDex Number 47
# Parsed Pokémon with PokéDex Number 48
# Parsed Pokémon with PokéDex Number 49
# Parsed Pokémon with PokéDex Number 50
# Parsed Pokémon with PokéDex Number 51
# Parsed Pokémon with PokéDex Number 52
# Parsed Pokémon with PokéDex Number 53
# Parsed Pokémon with PokéDex Number 54
# Parsed Pokémon with PokéDex Number 55
# Parsed Pokémon with PokéDex Number 56
# Parsed Pokémon with PokéDex Number 57
# Parsed Pokémon with PokéDex Number 58
# Parsed Pokémon with PokéDex Number 59
# Parsed Pokémon with PokéDex Number 60
# Parsed Pokémon with PokéDex Number 61
# Parsed Pokémon with PokéDex Number 62
# Parsed Pokémon with PokéDex Number 63
# Parsed Pokémon with PokéDex Number 64
# Parsed Pokémon with PokéDex Number 65
# Parsed Pokémon with PokéDex Number 66
# Parsed Pokémon with PokéDex Number 67
# Parsed Pokémon with PokéDex Number 68
# Parsed Pokémon with PokéDex Number 69
# Parsed Pokémon with PokéDex Number 70
# Parsed Pokémon with PokéDex Number 71
# Parsed Pokémon with PokéDex Number 72
# Parsed Pokémon with PokéDex Number 73
# Parsed Pokémon with PokéDex Number 74
# Parsed Pokémon with PokéDex Number 75
# Parsed Pokémon with PokéDex Number 76
# Parsed Pokémon with PokéDex Number 77
# Parsed Pokémon with PokéDex Number 78
# Parsed Pokémon with PokéDex Number 79
# Parsed Pokémon with PokéDex Number 80
# Parsed Pokémon with PokéDex Number 81
# Parsed Pokémon with PokéDex Number 82
# Parsed Pokémon with PokéDex Number 83
# Parsed Pokémon with PokéDex Number 84
# Parsed Pokémon with PokéDex Number 85
# Parsed Pokémon with PokéDex Number 86
# Parsed Pokémon with PokéDex Number 87
# Parsed Pokémon with PokéDex Number 88
# Parsed Pokémon with PokéDex Number 89
# Parsed Pokémon with PokéDex Number 90
# Parsed Pokémon with PokéDex Number 91
# Parsed Pokémon with PokéDex Number 92
# Parsed Pokémon with PokéDex Number 93
# Parsed Pokémon with PokéDex Number 94
# Parsed Pokémon with PokéDex Number 95
# Parsed Pokémon with PokéDex Number 96
# Parsed Pokémon with PokéDex Number 97
# Parsed Pokémon with PokéDex Number 98
# Parsed Pokémon with PokéDex Number 99
# Parsed Pokémon with PokéDex Number 100
# Parsed Pokémon with PokéDex Number 101
# Parsed Pokémon with PokéDex Number 102
# Parsed Pokémon with PokéDex Number 103
# Parsed Pokémon with PokéDex Number 104
# Parsed Pokémon with PokéDex Number 105
# Parsed Pokémon with PokéDex Number 106
# Parsed Pokémon with PokéDex Number 107
# Parsed Pokémon with PokéDex Number 108
# Parsed Pokémon with PokéDex Number 109
# Parsed Pokémon with PokéDex Number 110
# Parsed Pokémon with PokéDex Number 111
# Parsed Pokémon with PokéDex Number 112
# Parsed Pokémon with PokéDex Number 113
# Parsed Pokémon with PokéDex Number 114
# Parsed Pokémon with PokéDex Number 115
# Parsed Pokémon with PokéDex Number 116
# Parsed Pokémon with PokéDex Number 117
# Parsed Pokémon with PokéDex Number 118
# Parsed Pokémon with PokéDex Number 119
# Parsed Pokémon with PokéDex Number 120
# Parsed Pokémon with PokéDex Number 121
# Parsed Pokémon with PokéDex Number 122
# Parsed Pokémon with PokéDex Number 123
# Parsed Pokémon with PokéDex Number 124
# Parsed Pokémon with PokéDex Number 125
# Parsed Pokémon with PokéDex Number 126
# Parsed Pokémon with PokéDex Number 127
# Parsed Pokémon with PokéDex Number 128
# Parsed Pokémon with PokéDex Number 129
# Parsed Pokémon with PokéDex Number 130
# Parsed Pokémon with PokéDex Number 131
# Parsed Pokémon with PokéDex Number 132
# Parsed Pokémon with PokéDex Number 133
# Parsed Pokémon with PokéDex Number 134
# Parsed Pokémon with PokéDex Number 135
# Parsed Pokémon with PokéDex Number 136
# Parsed Pokémon with PokéDex Number 137
# Parsed Pokémon with PokéDex Number 138
# Parsed Pokémon with PokéDex Number 139
# Parsed Pokémon with PokéDex Number 140
# Parsed Pokémon with PokéDex Number 141
# Parsed Pokémon with PokéDex Number 142
# Parsed Pokémon with PokéDex Number 143
# Parsed Pokémon with PokéDex Number 144
# Parsed Pokémon with PokéDex Number 145
# Parsed Pokémon with PokéDex Number 146
# Parsed Pokémon with PokéDex Number 147
# Parsed Pokémon with PokéDex Number 148
# Parsed Pokémon with PokéDex Number 149
# Parsed Pokémon with PokéDex Number 150
# Parsed Pokémon with PokéDex Number 151
# Parsed Pokémon with PokéDex Number 152
# Parsed Pokémon with PokéDex Number 153
# Parsed Pokémon with PokéDex Number 154
# Parsed Pokémon with PokéDex Number 155
# Parsed Pokémon with PokéDex Number 156
# Parsed Pokémon with PokéDex Number 157
# Parsed Pokémon with PokéDex Number 158
# Parsed Pokémon with PokéDex Number 159
# Parsed Pokémon with PokéDex Number 160
# Parsed Pokémon with PokéDex Number 161
# Parsed Pokémon with PokéDex Number 162
# Parsed Pokémon with PokéDex Number 163
# Parsed Pokémon with PokéDex Number 164
# Parsed Pokémon with PokéDex Number 165
# Parsed Pokémon with PokéDex Number 166
# Parsed Pokémon with PokéDex Number 167
# Parsed Pokémon with PokéDex Number 168
# Parsed Pokémon with PokéDex Number 169
# Parsed Pokémon with PokéDex Number 170
# Parsed Pokémon with PokéDex Number 171
# Parsed Pokémon with PokéDex Number 172
# Parsed Pokémon with PokéDex Number 173
# Parsed Pokémon with PokéDex Number 174
# Parsed Pokémon with PokéDex Number 175
# Parsed Pokémon with PokéDex Number 176
# Parsed Pokémon with PokéDex Number 177
# Parsed Pokémon with PokéDex Number 178
# Parsed Pokémon with PokéDex Number 179
# Parsed Pokémon with PokéDex Number 180
# Parsed Pokémon with PokéDex Number 181
# Parsed Pokémon with PokéDex Number 182
# Parsed Pokémon with PokéDex Number 183
# Parsed Pokémon with PokéDex Number 184
# Parsed Pokémon with PokéDex Number 185
# Parsed Pokémon with PokéDex Number 186
# Parsed Pokémon with PokéDex Number 187
# Parsed Pokémon with PokéDex Number 188
# Parsed Pokémon with PokéDex Number 189
# Parsed Pokémon with PokéDex Number 190
# Parsed Pokémon with PokéDex Number 191
# Parsed Pokémon with PokéDex Number 192
# Parsed Pokémon with PokéDex Number 193
# Parsed Pokémon with PokéDex Number 194
# Parsed Pokémon with PokéDex Number 195
# Parsed Pokémon with PokéDex Number 196
# Parsed Pokémon with PokéDex Number 197
# Parsed Pokémon with PokéDex Number 198
# Parsed Pokémon with PokéDex Number 199
# Parsed Pokémon with PokéDex Number 200
# Parsed Pokémon with PokéDex Number 201
# Parsed Pokémon with PokéDex Number 202
# Parsed Pokémon with PokéDex Number 203
# Parsed Pokémon with PokéDex Number 204
# Parsed Pokémon with PokéDex Number 205
# Parsed Pokémon with PokéDex Number 206
# Parsed Pokémon with PokéDex Number 207
# Parsed Pokémon with PokéDex Number 208
# Parsed Pokémon with PokéDex Number 209
# Parsed Pokémon with PokéDex Number 210
# Parsed Pokémon with PokéDex Number 211
# Parsed Pokémon with PokéDex Number 212
# Parsed Pokémon with PokéDex Number 213
# Parsed Pokémon with PokéDex Number 214
# Parsed Pokémon with PokéDex Number 215
# Parsed Pokémon with PokéDex Number 216
# Parsed Pokémon with PokéDex Number 217
# Parsed Pokémon with PokéDex Number 218
# Parsed Pokémon with PokéDex Number 219
# Parsed Pokémon with PokéDex Number 220
# Parsed Pokémon with PokéDex Number 221
# Parsed Pokémon with PokéDex Number 222
# Parsed Pokémon with PokéDex Number 223
# Parsed Pokémon with PokéDex Number 224
# Parsed Pokémon with PokéDex Number 225
# Parsed Pokémon with PokéDex Number 226
# Parsed Pokémon with PokéDex Number 227
# Parsed Pokémon with PokéDex Number 228
# Parsed Pokémon with PokéDex Number 229
# Parsed Pokémon with PokéDex Number 230
# Parsed Pokémon with PokéDex Number 231
# Parsed Pokémon with PokéDex Number 232
# Parsed Pokémon with PokéDex Number 233
# Parsed Pokémon with PokéDex Number 234
# Parsed Pokémon with PokéDex Number 235
# Parsed Pokémon with PokéDex Number 236
# Parsed Pokémon with PokéDex Number 237
# Parsed Pokémon with PokéDex Number 238
# Parsed Pokémon with PokéDex Number 239
# Parsed Pokémon with PokéDex Number 240
# Parsed Pokémon with PokéDex Number 241
# Parsed Pokémon with PokéDex Number 242
# Parsed Pokémon with PokéDex Number 243
# Parsed Pokémon with PokéDex Number 244
# Parsed Pokémon with PokéDex Number 245
# Parsed Pokémon with PokéDex Number 246
# Parsed Pokémon with PokéDex Number 247
# Parsed Pokémon with PokéDex Number 248
# Parsed Pokémon with PokéDex Number 249
# Parsed Pokémon with PokéDex Number 250
# Parsed Pokémon with PokéDex Number 251
# Parsed Pokémon with PokéDex Number 252
# Parsed Pokémon with PokéDex Number 253
# Parsed Pokémon with PokéDex Number 254
# Parsed Pokémon with PokéDex Number 255
# Parsed Pokémon with PokéDex Number 256
# Parsed Pokémon with PokéDex Number 257
# Parsed Pokémon with PokéDex Number 258
# Parsed Pokémon with PokéDex Number 259
# Parsed Pokémon with PokéDex Number 260
# Parsed Pokémon with PokéDex Number 261
# Parsed Pokémon with PokéDex Number 262
# Parsed Pokémon with PokéDex Number 263
# Parsed Pokémon with PokéDex Number 264
# Parsed Pokémon with PokéDex Number 265
# Parsed Pokémon with PokéDex Number 266
# Parsed Pokémon with PokéDex Number 267
# Parsed Pokémon with PokéDex Number 268
# Parsed Pokémon with PokéDex Number 269
# Parsed Pokémon with PokéDex Number 270
# Parsed Pokémon with PokéDex Number 271
# Parsed Pokémon with PokéDex Number 272
# Parsed Pokémon with PokéDex Number 273
# Parsed Pokémon with PokéDex Number 274
# Parsed Pokémon with PokéDex Number 275
# Parsed Pokémon with PokéDex Number 276
# Parsed Pokémon with PokéDex Number 277
# Parsed Pokémon with PokéDex Number 278
# Parsed Pokémon with PokéDex Number 279
# Parsed Pokémon with PokéDex Number 280
# Parsed Pokémon with PokéDex Number 281
# Parsed Pokémon with PokéDex Number 282
# Parsed Pokémon with PokéDex Number 283
# Parsed Pokémon with PokéDex Number 284
# Parsed Pokémon with PokéDex Number 285
# Parsed Pokémon with PokéDex Number 286
# Parsed Pokémon with PokéDex Number 287
# Parsed Pokémon with PokéDex Number 288
# Parsed Pokémon with PokéDex Number 289
# Parsed Pokémon with PokéDex Number 290
# Parsed Pokémon with PokéDex Number 291
# Parsed Pokémon with PokéDex Number 292
# Parsed Pokémon with PokéDex Number 293
# Parsed Pokémon with PokéDex Number 294
# Parsed Pokémon with PokéDex Number 295
# Parsed Pokémon with PokéDex Number 296
# Parsed Pokémon with PokéDex Number 297
# Parsed Pokémon with PokéDex Number 298
# Parsed Pokémon with PokéDex Number 299
# Parsed Pokémon with PokéDex Number 300
# Parsed Pokémon with PokéDex Number 301
# Parsed Pokémon with PokéDex Number 302
# Parsed Pokémon with PokéDex Number 303
# Parsed Pokémon with PokéDex Number 304
# Parsed Pokémon with PokéDex Number 305
# Parsed Pokémon with PokéDex Number 306
# Parsed Pokémon with PokéDex Number 307
# Parsed Pokémon with PokéDex Number 308
# Parsed Pokémon with PokéDex Number 309
# Parsed Pokémon with PokéDex Number 310
# Parsed Pokémon with PokéDex Number 311
# Parsed Pokémon with PokéDex Number 312
# Parsed Pokémon with PokéDex Number 313
# Parsed Pokémon with PokéDex Number 314
# Parsed Pokémon with PokéDex Number 315
# Parsed Pokémon with PokéDex Number 316
# Parsed Pokémon with PokéDex Number 317
# Parsed Pokémon with PokéDex Number 318
# Parsed Pokémon with PokéDex Number 319
# Parsed Pokémon with PokéDex Number 320
# Parsed Pokémon with PokéDex Number 321
# Parsed Pokémon with PokéDex Number 322
# Parsed Pokémon with PokéDex Number 323
# Parsed Pokémon with PokéDex Number 324
# Parsed Pokémon with PokéDex Number 325
# Parsed Pokémon with PokéDex Number 326
# Parsed Pokémon with PokéDex Number 327
# Parsed Pokémon with PokéDex Number 328
# Parsed Pokémon with PokéDex Number 329
# Parsed Pokémon with PokéDex Number 330
# Parsed Pokémon with PokéDex Number 331
# Parsed Pokémon with PokéDex Number 332
# Parsed Pokémon with PokéDex Number 333
# Parsed Pokémon with PokéDex Number 334
# Parsed Pokémon with PokéDex Number 335
# Parsed Pokémon with PokéDex Number 336
# Parsed Pokémon with PokéDex Number 337
# Parsed Pokémon with PokéDex Number 338
# Parsed Pokémon with PokéDex Number 339
# Parsed Pokémon with PokéDex Number 340
# Parsed Pokémon with PokéDex Number 341
# Parsed Pokémon with PokéDex Number 342
# Parsed Pokémon with PokéDex Number 343
# Parsed Pokémon with PokéDex Number 344
# Parsed Pokémon with PokéDex Number 345
# Parsed Pokémon with PokéDex Number 346
# Parsed Pokémon with PokéDex Number 347
# Parsed Pokémon with PokéDex Number 348
# Parsed Pokémon with PokéDex Number 349
# Parsed Pokémon with PokéDex Number 350
# Parsed Pokémon with PokéDex Number 351
# Parsed Pokémon with PokéDex Number 352
# Parsed Pokémon with PokéDex Number 353
# Parsed Pokémon with PokéDex Number 354
# Parsed Pokémon with PokéDex Number 355
# Parsed Pokémon with PokéDex Number 356
# Parsed Pokémon with PokéDex Number 357
# Parsed Pokémon with PokéDex Number 358
# Parsed Pokémon with PokéDex Number 359
# Parsed Pokémon with PokéDex Number 360
# Parsed Pokémon with PokéDex Number 361
# Parsed Pokémon with PokéDex Number 362
# Parsed Pokémon with PokéDex Number 363
# Parsed Pokémon with PokéDex Number 364
# Parsed Pokémon with PokéDex Number 365
# Parsed Pokémon with PokéDex Number 366
# Parsed Pokémon with PokéDex Number 367
# Parsed Pokémon with PokéDex Number 368
# Parsed Pokémon with PokéDex Number 369
# Parsed Pokémon with PokéDex Number 370
# Parsed Pokémon with PokéDex Number 371
# Parsed Pokémon with PokéDex Number 372
# Parsed Pokémon with PokéDex Number 373
# Parsed Pokémon with PokéDex Number 374
# Parsed Pokémon with PokéDex Number 375
# Parsed Pokémon with PokéDex Number 376
# Parsed Pokémon with PokéDex Number 377
# Parsed Pokémon with PokéDex Number 378
# Parsed Pokémon with PokéDex Number 379
# Parsed Pokémon with PokéDex Number 380
# Parsed Pokémon with PokéDex Number 381
# Parsed Pokémon with PokéDex Number 382
# Parsed Pokémon with PokéDex Number 383
# Parsed Pokémon with PokéDex Number 384
# Parsed Pokémon with PokéDex Number 385
# Parsed Pokémon with PokéDex Number 386
# Parsed Pokémon with PokéDex Number 387
# Parsed Pokémon with PokéDex Number 388
# Parsed Pokémon with PokéDex Number 389
# Parsed Pokémon with PokéDex Number 390
# Parsed Pokémon with PokéDex Number 391
# Parsed Pokémon with PokéDex Number 392
# Parsed Pokémon with PokéDex Number 393
# Parsed Pokémon with PokéDex Number 394
# Parsed Pokémon with PokéDex Number 395
# Parsed Pokémon with PokéDex Number 396
# Parsed Pokémon with PokéDex Number 397
# Parsed Pokémon with PokéDex Number 398
# Parsed Pokémon with PokéDex Number 399
# Parsed Pokémon with PokéDex Number 400
# Parsed Pokémon with PokéDex Number 401
# Parsed Pokémon with PokéDex Number 402
# Parsed Pokémon with PokéDex Number 403
# Parsed Pokémon with PokéDex Number 404
# Parsed Pokémon with PokéDex Number 405
# Parsed Pokémon with PokéDex Number 406
# Parsed Pokémon with PokéDex Number 407
# Parsed Pokémon with PokéDex Number 408
# Parsed Pokémon with PokéDex Number 409
# Parsed Pokémon with PokéDex Number 410
# Parsed Pokémon with PokéDex Number 411
# Parsed Pokémon with PokéDex Number 412
# Parsed Pokémon with PokéDex Number 413
# Parsed Pokémon with PokéDex Number 414
# Parsed Pokémon with PokéDex Number 415
# Parsed Pokémon with PokéDex Number 416
# Parsed Pokémon with PokéDex Number 417
# Parsed Pokémon with PokéDex Number 418
# Parsed Pokémon with PokéDex Number 419
# Parsed Pokémon with PokéDex Number 420
# Parsed Pokémon with PokéDex Number 421
# Parsed Pokémon with PokéDex Number 422
# Parsed Pokémon with PokéDex Number 423
# Parsed Pokémon with PokéDex Number 424
# Parsed Pokémon with PokéDex Number 425
# Parsed Pokémon with PokéDex Number 426
# Parsed Pokémon with PokéDex Number 427
# Parsed Pokémon with PokéDex Number 428
# Parsed Pokémon with PokéDex Number 429
# Parsed Pokémon with PokéDex Number 430
# Parsed Pokémon with PokéDex Number 431
# Parsed Pokémon with PokéDex Number 432
# Parsed Pokémon with PokéDex Number 433
# Parsed Pokémon with PokéDex Number 434
# Parsed Pokémon with PokéDex Number 435
# Parsed Pokémon with PokéDex Number 436
# Parsed Pokémon with PokéDex Number 437
# Parsed Pokémon with PokéDex Number 438
# Parsed Pokémon with PokéDex Number 439
# Parsed Pokémon with PokéDex Number 440
# Parsed Pokémon with PokéDex Number 441
# Parsed Pokémon with PokéDex Number 442
# Parsed Pokémon with PokéDex Number 443
# Parsed Pokémon with PokéDex Number 444
# Parsed Pokémon with PokéDex Number 445
# Parsed Pokémon with PokéDex Number 446
# Parsed Pokémon with PokéDex Number 447
# Parsed Pokémon with PokéDex Number 448
# Parsed Pokémon with PokéDex Number 449
# Parsed Pokémon with PokéDex Number 450
# Parsed Pokémon with PokéDex Number 451
# Parsed Pokémon with PokéDex Number 452
# Parsed Pokémon with PokéDex Number 453
# Parsed Pokémon with PokéDex Number 454
# Parsed Pokémon with PokéDex Number 455
# Parsed Pokémon with PokéDex Number 456
# Parsed Pokémon with PokéDex Number 457
# Parsed Pokémon with PokéDex Number 458
# Parsed Pokémon with PokéDex Number 459
# Parsed Pokémon with PokéDex Number 460
# Parsed Pokémon with PokéDex Number 461
# Parsed Pokémon with PokéDex Number 462
# Parsed Pokémon with PokéDex Number 463
# Parsed Pokémon with PokéDex Number 464
# Parsed Pokémon with PokéDex Number 465
# Parsed Pokémon with PokéDex Number 466
# Parsed Pokémon with PokéDex Number 467
# Parsed Pokémon with PokéDex Number 468
# Parsed Pokémon with PokéDex Number 469
# Parsed Pokémon with PokéDex Number 470
# Parsed Pokémon with PokéDex Number 471
# Parsed Pokémon with PokéDex Number 472
# Parsed Pokémon with PokéDex Number 473
# Parsed Pokémon with PokéDex Number 474
# Parsed Pokémon with PokéDex Number 475
# Parsed Pokémon with PokéDex Number 476
# Parsed Pokémon with PokéDex Number 477
# Parsed Pokémon with PokéDex Number 478
# Parsed Pokémon with PokéDex Number 479
# Parsed Pokémon with PokéDex Number 480
# Parsed Pokémon with PokéDex Number 481
# Parsed Pokémon with PokéDex Number 482
# Parsed Pokémon with PokéDex Number 483
# Parsed Pokémon with PokéDex Number 484
# Parsed Pokémon with PokéDex Number 485
# Parsed Pokémon with PokéDex Number 486
# Parsed Pokémon with PokéDex Number 487
# Parsed Pokémon with PokéDex Number 488
# Parsed Pokémon with PokéDex Number 489
# Parsed Pokémon with PokéDex Number 490
# Parsed Pokémon with PokéDex Number 491
# Parsed Pokémon with PokéDex Number 492
# Parsed Pokémon with PokéDex Number 493
# Parsed Pokémon with PokéDex Number 494
# Parsed Pokémon with PokéDex Number 495
# Parsed Pokémon with PokéDex Number 496
# Parsed Pokémon with PokéDex Number 497
# Parsed Pokémon with PokéDex Number 498
# Parsed Pokémon with PokéDex Number 499
# Parsed Pokémon with PokéDex Number 500
# Parsed Pokémon with PokéDex Number 501
# Parsed Pokémon with PokéDex Number 502
# Parsed Pokémon with PokéDex Number 503
# Parsed Pokémon with PokéDex Number 504
# Parsed Pokémon with PokéDex Number 505
# Parsed Pokémon with PokéDex Number 506
# Parsed Pokémon with PokéDex Number 507
# Parsed Pokémon with PokéDex Number 508
# Parsed Pokémon with PokéDex Number 509
# Parsed Pokémon with PokéDex Number 510
# Parsed Pokémon with PokéDex Number 511
# Parsed Pokémon with PokéDex Number 512
# Parsed Pokémon with PokéDex Number 513
# Parsed Pokémon with PokéDex Number 514
# Parsed Pokémon with PokéDex Number 515
# Parsed Pokémon with PokéDex Number 516
# Parsed Pokémon with PokéDex Number 517
# Parsed Pokémon with PokéDex Number 518
# Parsed Pokémon with PokéDex Number 519
# Parsed Pokémon with PokéDex Number 520
# Parsed Pokémon with PokéDex Number 521
# Parsed Pokémon with PokéDex Number 522
# Parsed Pokémon with PokéDex Number 523
# Parsed Pokémon with PokéDex Number 524
# Parsed Pokémon with PokéDex Number 525
# Parsed Pokémon with PokéDex Number 526
# Parsed Pokémon with PokéDex Number 527
# Parsed Pokémon with PokéDex Number 528
# Parsed Pokémon with PokéDex Number 529
# Parsed Pokémon with PokéDex Number 530
# Parsed Pokémon with PokéDex Number 531
# Parsed Pokémon with PokéDex Number 532
# Parsed Pokémon with PokéDex Number 533
# Parsed Pokémon with PokéDex Number 534
# Parsed Pokémon with PokéDex Number 535
# Parsed Pokémon with PokéDex Number 536
# Parsed Pokémon with PokéDex Number 537
# Parsed Pokémon with PokéDex Number 538
# Parsed Pokémon with PokéDex Number 539
# Parsed Pokémon with PokéDex Number 540
# Parsed Pokémon with PokéDex Number 541
# Parsed Pokémon with PokéDex Number 542
# Parsed Pokémon with PokéDex Number 543
# Parsed Pokémon with PokéDex Number 544
# Parsed Pokémon with PokéDex Number 545
# Parsed Pokémon with PokéDex Number 546
# Parsed Pokémon with PokéDex Number 547
# Parsed Pokémon with PokéDex Number 548
# Parsed Pokémon with PokéDex Number 549
# Parsed Pokémon with PokéDex Number 550
# Parsed Pokémon with PokéDex Number 551
# Parsed Pokémon with PokéDex Number 552
# Parsed Pokémon with PokéDex Number 553
# Parsed Pokémon with PokéDex Number 554
# Parsed Pokémon with PokéDex Number 555
# Parsed Pokémon with PokéDex Number 556
# Parsed Pokémon with PokéDex Number 557
# Parsed Pokémon with PokéDex Number 558
# Parsed Pokémon with PokéDex Number 559
# Parsed Pokémon with PokéDex Number 560
# Parsed Pokémon with PokéDex Number 561
# Parsed Pokémon with PokéDex Number 562
# Parsed Pokémon with PokéDex Number 563
# Parsed Pokémon with PokéDex Number 564
# Parsed Pokémon with PokéDex Number 565
# Parsed Pokémon with PokéDex Number 566
# Parsed Pokémon with PokéDex Number 567
# Parsed Pokémon with PokéDex Number 568
# Parsed Pokémon with PokéDex Number 569
# Parsed Pokémon with PokéDex Number 570
# Parsed Pokémon with PokéDex Number 571
# Parsed Pokémon with PokéDex Number 572
# Parsed Pokémon with PokéDex Number 573
# Parsed Pokémon with PokéDex Number 574
# Parsed Pokémon with PokéDex Number 575
# Parsed Pokémon with PokéDex Number 576
# Parsed Pokémon with PokéDex Number 577
# Parsed Pokémon with PokéDex Number 578
# Parsed Pokémon with PokéDex Number 579
# Parsed Pokémon with PokéDex Number 580
# Parsed Pokémon with PokéDex Number 581
# Parsed Pokémon with PokéDex Number 582
# Parsed Pokémon with PokéDex Number 583
# Parsed Pokémon with PokéDex Number 584
# Parsed Pokémon with PokéDex Number 585
# Parsed Pokémon with PokéDex Number 586
# Parsed Pokémon with PokéDex Number 587
# Parsed Pokémon with PokéDex Number 588
# Parsed Pokémon with PokéDex Number 589
# Parsed Pokémon with PokéDex Number 590
# Parsed Pokémon with PokéDex Number 591
# Parsed Pokémon with PokéDex Number 592
# Parsed Pokémon with PokéDex Number 593
# Parsed Pokémon with PokéDex Number 594
# Parsed Pokémon with PokéDex Number 595
# Parsed Pokémon with PokéDex Number 596
# Parsed Pokémon with PokéDex Number 597
# Parsed Pokémon with PokéDex Number 598
# Parsed Pokémon with PokéDex Number 599
# Parsed Pokémon with PokéDex Number 600
# Parsed Pokémon with PokéDex Number 601
# Parsed Pokémon with PokéDex Number 602
# Parsed Pokémon with PokéDex Number 603
# Parsed Pokémon with PokéDex Number 604
# Parsed Pokémon with PokéDex Number 605
# Parsed Pokémon with PokéDex Number 606
# Parsed Pokémon with PokéDex Number 607
# Parsed Pokémon with PokéDex Number 608
# Parsed Pokémon with PokéDex Number 609
# Parsed Pokémon with PokéDex Number 610
# Parsed Pokémon with PokéDex Number 611
# Parsed Pokémon with PokéDex Number 612
# Parsed Pokémon with PokéDex Number 613
# Parsed Pokémon with PokéDex Number 614
# Parsed Pokémon with PokéDex Number 615
# Parsed Pokémon with PokéDex Number 616
# Parsed Pokémon with PokéDex Number 617
# Parsed Pokémon with PokéDex Number 618
# Parsed Pokémon with PokéDex Number 619
# Parsed Pokémon with PokéDex Number 620
# Parsed Pokémon with PokéDex Number 621
# Parsed Pokémon with PokéDex Number 622
# Parsed Pokémon with PokéDex Number 623
# Parsed Pokémon with PokéDex Number 624
# Parsed Pokémon with PokéDex Number 625
# Parsed Pokémon with PokéDex Number 626
# Parsed Pokémon with PokéDex Number 627
# Parsed Pokémon with PokéDex Number 628
# Parsed Pokémon with PokéDex Number 629
# Parsed Pokémon with PokéDex Number 630
# Parsed Pokémon with PokéDex Number 631
# Parsed Pokémon with PokéDex Number 632
# Parsed Pokémon with PokéDex Number 633
# Parsed Pokémon with PokéDex Number 634
# Parsed Pokémon with PokéDex Number 635
# Parsed Pokémon with PokéDex Number 636
# Parsed Pokémon with PokéDex Number 637
# Parsed Pokémon with PokéDex Number 638
# Parsed Pokémon with PokéDex Number 639
# Parsed Pokémon with PokéDex Number 640
# Parsed Pokémon with PokéDex Number 641
# Parsed Pokémon with PokéDex Number 642
# Parsed Pokémon with PokéDex Number 643
# Parsed Pokémon with PokéDex Number 644
# Parsed Pokémon with PokéDex Number 645
# Parsed Pokémon with PokéDex Number 646
# Parsed Pokémon with PokéDex Number 647
# Parsed Pokémon with PokéDex Number 648
# Parsed Pokémon with PokéDex Number 649
# Parsed Pokémon with PokéDex Number 650
# Parsed Pokémon with PokéDex Number 651
# Parsed Pokémon with PokéDex Number 652
# Parsed Pokémon with PokéDex Number 653
# Parsed Pokémon with PokéDex Number 654
# Parsed Pokémon with PokéDex Number 655
# Parsed Pokémon with PokéDex Number 656
# Parsed Pokémon with PokéDex Number 657
# Parsed Pokémon with PokéDex Number 658
# Parsed Pokémon with PokéDex Number 659
# Parsed Pokémon with PokéDex Number 660
# Parsed Pokémon with PokéDex Number 661
# Parsed Pokémon with PokéDex Number 662
# Parsed Pokémon with PokéDex Number 663
# Parsed Pokémon with PokéDex Number 664
# Parsed Pokémon with PokéDex Number 665
# Parsed Pokémon with PokéDex Number 666
# Parsed Pokémon with PokéDex Number 667
# Parsed Pokémon with PokéDex Number 668
# Parsed Pokémon with PokéDex Number 669
# Parsed Pokémon with PokéDex Number 670
# Parsed Pokémon with PokéDex Number 671
# Parsed Pokémon with PokéDex Number 672
# Parsed Pokémon with PokéDex Number 673
# Parsed Pokémon with PokéDex Number 674
# Parsed Pokémon with PokéDex Number 675
# Parsed Pokémon with PokéDex Number 676
# Parsed Pokémon with PokéDex Number 677
# Parsed Pokémon with PokéDex Number 678
# Parsed Pokémon with PokéDex Number 679
# Parsed Pokémon with PokéDex Number 680
# Parsed Pokémon with PokéDex Number 681
# Parsed Pokémon with PokéDex Number 682
# Parsed Pokémon with PokéDex Number 683
# Parsed Pokémon with PokéDex Number 684
# Parsed Pokémon with PokéDex Number 685
# Parsed Pokémon with PokéDex Number 686
# Parsed Pokémon with PokéDex Number 687
# Parsed Pokémon with PokéDex Number 688
# Parsed Pokémon with PokéDex Number 689
# Parsed Pokémon with PokéDex Number 690
# Parsed Pokémon with PokéDex Number 691
# Parsed Pokémon with PokéDex Number 692
# Parsed Pokémon with PokéDex Number 693
# Parsed Pokémon with PokéDex Number 694
# Parsed Pokémon with PokéDex Number 695
# Parsed Pokémon with PokéDex Number 696
# Parsed Pokémon with PokéDex Number 697
# Parsed Pokémon with PokéDex Number 698
# Parsed Pokémon with PokéDex Number 699
# Parsed Pokémon with PokéDex Number 700
# Parsed Pokémon with PokéDex Number 701
# Parsed Pokémon with PokéDex Number 702
# Parsed Pokémon with PokéDex Number 703
# Parsed Pokémon with PokéDex Number 704
# Parsed Pokémon with PokéDex Number 705
# Parsed Pokémon with PokéDex Number 706
# Parsed Pokémon with PokéDex Number 707
# Parsed Pokémon with PokéDex Number 708
# Parsed Pokémon with PokéDex Number 709
# Parsed Pokémon with PokéDex Number 710
# Parsed Pokémon with PokéDex Number 711
# Parsed Pokémon with PokéDex Number 712
# Parsed Pokémon with PokéDex Number 713
# Parsed Pokémon with PokéDex Number 714
# Parsed Pokémon with PokéDex Number 715
# Parsed Pokémon with PokéDex Number 716
# Parsed Pokémon with PokéDex Number 717
# Parsed Pokémon with PokéDex Number 718
# Parsed Pokémon with PokéDex Number 719
# Parsed Pokémon with PokéDex Number 720
# Parsed Pokémon with PokéDex Number 721
# Parsed Pokémon with PokéDex Number 722
# Parsed Pokémon with PokéDex Number 723
# Parsed Pokémon with PokéDex Number 724
# Parsed Pokémon with PokéDex Number 725
# Parsed Pokémon with PokéDex Number 726
# Parsed Pokémon with PokéDex Number 727
# Parsed Pokémon with PokéDex Number 728
# Parsed Pokémon with PokéDex Number 729
# Parsed Pokémon with PokéDex Number 730
# Parsed Pokémon with PokéDex Number 731
# Parsed Pokémon with PokéDex Number 732
# Parsed Pokémon with PokéDex Number 733
# Parsed Pokémon with PokéDex Number 734
# Parsed Pokémon with PokéDex Number 735
# Parsed Pokémon with PokéDex Number 736
# Parsed Pokémon with PokéDex Number 737
# Parsed Pokémon with PokéDex Number 738
# Parsed Pokémon with PokéDex Number 739
# Parsed Pokémon with PokéDex Number 740
# Parsed Pokémon with PokéDex Number 741
# Parsed Pokémon with PokéDex Number 742
# Parsed Pokémon with PokéDex Number 743
# Parsed Pokémon with PokéDex Number 744
# Parsed Pokémon with PokéDex Number 745
# Parsed Pokémon with PokéDex Number 746
# Parsed Pokémon with PokéDex Number 747
# Parsed Pokémon with PokéDex Number 748
# Parsed Pokémon with PokéDex Number 749
# Parsed Pokémon with PokéDex Number 750
# Parsed Pokémon with PokéDex Number 751
# Parsed Pokémon with PokéDex Number 752
# Parsed Pokémon with PokéDex Number 753
# Parsed Pokémon with PokéDex Number 754
# Parsed Pokémon with PokéDex Number 755
# Parsed Pokémon with PokéDex Number 756
# Parsed Pokémon with PokéDex Number 757
# Parsed Pokémon with PokéDex Number 758
# Parsed Pokémon with PokéDex Number 759
# Parsed Pokémon with PokéDex Number 760
# Parsed Pokémon with PokéDex Number 761
# Parsed Pokémon with PokéDex Number 762
# Parsed Pokémon with PokéDex Number 763
# Parsed Pokémon with PokéDex Number 764
# Parsed Pokémon with PokéDex Number 765
# Parsed Pokémon with PokéDex Number 766
# Parsed Pokémon with PokéDex Number 767
# Parsed Pokémon with PokéDex Number 768
# Parsed Pokémon with PokéDex Number 769
# Parsed Pokémon with PokéDex Number 770
# Parsed Pokémon with PokéDex Number 771
# Parsed Pokémon with PokéDex Number 772
# Parsed Pokémon with PokéDex Number 773
# Parsed Pokémon with PokéDex Number 774
# Parsed Pokémon with PokéDex Number 775
# Parsed Pokémon with PokéDex Number 776
# Parsed Pokémon with PokéDex Number 777
# Parsed Pokémon with PokéDex Number 778
# Parsed Pokémon with PokéDex Number 779
# Parsed Pokémon with PokéDex Number 780
# Parsed Pokémon with PokéDex Number 781
# Parsed Pokémon with PokéDex Number 782
# Parsed Pokémon with PokéDex Number 783
# Parsed Pokémon with PokéDex Number 784
# Parsed Pokémon with PokéDex Number 785
# Parsed Pokémon with PokéDex Number 786
# Parsed Pokémon with PokéDex Number 787
# Parsed Pokémon with PokéDex Number 788
# Parsed Pokémon with PokéDex Number 789
# Parsed Pokémon with PokéDex Number 790
# Parsed Pokémon with PokéDex Number 791
# Parsed Pokémon with PokéDex Number 792
# Parsed Pokémon with PokéDex Number 793
# Parsed Pokémon with PokéDex Number 794
# Parsed Pokémon with PokéDex Number 795
# Parsed Pokémon with PokéDex Number 796
# Parsed Pokémon with PokéDex Number 797
# Parsed Pokémon with PokéDex Number 798
# Parsed Pokémon with PokéDex Number 799
# Parsed Pokémon with PokéDex Number 800
# Parsed Pokémon with PokéDex Number 801
# Parsed Pokémon with PokéDex Number 802
# Parsed Pokémon with PokéDex Number 803
# Parsed Pokémon with PokéDex Number 804
# Parsed Pokémon with PokéDex Number 805
# Parsed Pokémon with PokéDex Number 806
# Parsed Pokémon with PokéDex Number 807
# Parsed Pokémon with PokéDex Number 808
# Parsed Pokémon with PokéDex Number 809
# Parsed Pokémon with PokéDex Number 810
# Parsed Pokémon with PokéDex Number 811
# Parsed Pokémon with PokéDex Number 812
# Parsed Pokémon with PokéDex Number 813
# Parsed Pokémon with PokéDex Number 814
# Parsed Pokémon with PokéDex Number 815
# Parsed Pokémon with PokéDex Number 816
# Parsed Pokémon with PokéDex Number 817
# Parsed Pokémon with PokéDex Number 818
# Parsed Pokémon with PokéDex Number 819
# Parsed Pokémon with PokéDex Number 820
# Parsed Pokémon with PokéDex Number 821
# Parsed Pokémon with PokéDex Number 822
# Parsed Pokémon with PokéDex Number 823
# Parsed Pokémon with PokéDex Number 824
# Parsed Pokémon with PokéDex Number 825
# Parsed Pokémon with PokéDex Number 826
# Parsed Pokémon with PokéDex Number 827
# Parsed Pokémon with PokéDex Number 828
# Parsed Pokémon with PokéDex Number 829
# Parsed Pokémon with PokéDex Number 830
# Parsed Pokémon with PokéDex Number 831
# Parsed Pokémon with PokéDex Number 832
# Parsed Pokémon with PokéDex Number 833
# Parsed Pokémon with PokéDex Number 834
# Parsed Pokémon with PokéDex Number 835
# Parsed Pokémon with PokéDex Number 836
# Parsed Pokémon with PokéDex Number 837
# Parsed Pokémon with PokéDex Number 838
# Parsed Pokémon with PokéDex Number 839
# Parsed Pokémon with PokéDex Number 840
# Parsed Pokémon with PokéDex Number 841
# Parsed Pokémon with PokéDex Number 842
# Parsed Pokémon with PokéDex Number 843
# Parsed Pokémon with PokéDex Number 844
# Parsed Pokémon with PokéDex Number 845
# Parsed Pokémon with PokéDex Number 846
# Parsed Pokémon with PokéDex Number 847
# Parsed Pokémon with PokéDex Number 848
# Parsed Pokémon with PokéDex Number 849
# Parsed Pokémon with PokéDex Number 850
# Parsed Pokémon with PokéDex Number 851
# Parsed Pokémon with PokéDex Number 852
# Parsed Pokémon with PokéDex Number 853
# Parsed Pokémon with PokéDex Number 854
# Parsed Pokémon with PokéDex Number 855
# Parsed Pokémon with PokéDex Number 856
# Parsed Pokémon with PokéDex Number 857
# Parsed Pokémon with PokéDex Number 858
# Parsed Pokémon with PokéDex Number 859
# Parsed Pokémon with PokéDex Number 860
# Parsed Pokémon with PokéDex Number 861
# Parsed Pokémon with PokéDex Number 862
# Parsed Pokémon with PokéDex Number 863
# Parsed Pokémon with PokéDex Number 864
# Parsed Pokémon with PokéDex Number 865
# Parsed Pokémon with PokéDex Number 866
# Parsed Pokémon with PokéDex Number 867
# Parsed Pokémon with PokéDex Number 868
# Parsed Pokémon with PokéDex Number 869
# Parsed Pokémon with PokéDex Number 870
# Parsed Pokémon with PokéDex Number 871
# Parsed Pokémon with PokéDex Number 872
# Parsed Pokémon with PokéDex Number 873
# Parsed Pokémon with PokéDex Number 874
# Parsed Pokémon with PokéDex Number 875
# Parsed Pokémon with PokéDex Number 876
# Parsed Pokémon with PokéDex Number 877
# Parsed Pokémon with PokéDex Number 878
# Parsed Pokémon with PokéDex Number 879
# Parsed Pokémon with PokéDex Number 880
# Parsed Pokémon with PokéDex Number 881
# Parsed Pokémon with PokéDex Number 882
# Parsed Pokémon with PokéDex Number 883
# Parsed Pokémon with PokéDex Number 884
# Parsed Pokémon with PokéDex Number 885
# Parsed Pokémon with PokéDex Number 886
# Parsed Pokémon with PokéDex Number 887
# Parsed Pokémon with PokéDex Number 888
# Parsed Pokémon with PokéDex Number 889
# Parsed Pokémon with PokéDex Number 890
# Parsed Pokémon with PokéDex Number 891
# Parsed Pokémon with PokéDex Number 892
# Parsed Pokémon with PokéDex Number 893
# Parsed Pokémon with PokéDex Number 894
# Parsed Pokémon with PokéDex Number 895
# Parsed Pokémon with PokéDex Number 896
# Parsed Pokémon with PokéDex Number 897
# Parsed Pokémon with PokéDex Number 898
# Parsed Pokémon with PokéDex Number 899
# Parsed Pokémon with PokéDex Number 900
# Parsed Pokémon with PokéDex Number 901
# Parsed Pokémon with PokéDex Number 902
# Parsed Pokémon with PokéDex Number 903
# Parsed Pokémon with PokéDex Number 904
# Parsed Pokémon with PokéDex Number 905
# Parsed Pokémon with PokéDex Number 906
# Parsed Pokémon with PokéDex Number 907
# Parsed Pokémon with PokéDex Number 908
# Parsed Pokémon with PokéDex Number 909
# Parsed Pokémon with PokéDex Number 910
# Parsed Pokémon with PokéDex Number 911
# Parsed Pokémon with PokéDex Number 912
# Parsed Pokémon with PokéDex Number 913
# Parsed Pokémon with PokéDex Number 914
# Parsed Pokémon with PokéDex Number 915
# Parsed Pokémon with PokéDex Number 916
# Parsed Pokémon with PokéDex Number 917
# Parsed Pokémon with PokéDex Number 918
# Parsed Pokémon with PokéDex Number 919
# Parsed Pokémon with PokéDex Number 920
# Parsed Pokémon with PokéDex Number 921
# Parsed Pokémon with PokéDex Number 922
# Parsed Pokémon with PokéDex Number 923
# Parsed Pokémon with PokéDex Number 924
# Parsed Pokémon with PokéDex Number 925
# Parsed Pokémon with PokéDex Number 926
# Parsed Pokémon with PokéDex Number 927
# Parsed Pokémon with PokéDex Number 928
# Parsed Pokémon with PokéDex Number 929
# Parsed Pokémon with PokéDex Number 930
# Parsed Pokémon with PokéDex Number 931
# Parsed Pokémon with PokéDex Number 932
# Parsed Pokémon with PokéDex Number 933
# Parsed Pokémon with PokéDex Number 934
# Parsed Pokémon with PokéDex Number 935
# Parsed Pokémon with PokéDex Number 936
# Parsed Pokémon with PokéDex Number 937
# Parsed Pokémon with PokéDex Number 938
# Parsed Pokémon with PokéDex Number 939
# Parsed Pokémon with PokéDex Number 940
# Parsed Pokémon with PokéDex Number 941
# Parsed Pokémon with PokéDex Number 942
# Parsed Pokémon with PokéDex Number 943
# Parsed Pokémon with PokéDex Number 944
# Parsed Pokémon with PokéDex Number 945
# Parsed Pokémon with PokéDex Number 946
# Parsed Pokémon with PokéDex Number 947
# Parsed Pokémon with PokéDex Number 948
# Parsed Pokémon with PokéDex Number 949
# Parsed Pokémon with PokéDex Number 950
# Parsed Pokémon with PokéDex Number 951
# Parsed Pokémon with PokéDex Number 952
# Parsed Pokémon with PokéDex Number 953
# Parsed Pokémon with PokéDex Number 954
# Parsed Pokémon with PokéDex Number 955
# Parsed Pokémon with PokéDex Number 956
# Parsed Pokémon with PokéDex Number 957
# Parsed Pokémon with PokéDex Number 958
# Parsed Pokémon with PokéDex Number 959
# Parsed Pokémon with PokéDex Number 960
# Parsed Pokémon with PokéDex Number 961
# Parsed Pokémon with PokéDex Number 962
# Parsed Pokémon with PokéDex Number 963
# Parsed Pokémon with PokéDex Number 964
# Parsed Pokémon with PokéDex Number 965
# Parsed Pokémon with PokéDex Number 966
# Parsed Pokémon with PokéDex Number 967
# Parsed Pokémon with PokéDex Number 968
# Parsed Pokémon with PokéDex Number 969
# Parsed Pokémon with PokéDex Number 970
# Parsed Pokémon with PokéDex Number 971
# Parsed Pokémon with PokéDex Number 972
# Parsed Pokémon with PokéDex Number 973
# Parsed Pokémon with PokéDex Number 974
# Parsed Pokémon with PokéDex Number 975
# Parsed Pokémon with PokéDex Number 976
# Parsed Pokémon with PokéDex Number 977
# Parsed Pokémon with PokéDex Number 978
# Parsed Pokémon with PokéDex Number 979
# Parsed Pokémon with PokéDex Number 980
# Parsed Pokémon with PokéDex Number 981
# Parsed Pokémon with PokéDex Number 982
# Parsed Pokémon with PokéDex Number 983
# Parsed Pokémon with PokéDex Number 984
# Parsed Pokémon with PokéDex Number 985
# Parsed Pokémon with PokéDex Number 986
# Parsed Pokémon with PokéDex Number 987
# Parsed Pokémon with PokéDex Number 988
# Parsed Pokémon with PokéDex Number 989
# Parsed Pokémon with PokéDex Number 990
# Parsed Pokémon with PokéDex Number 991
# Parsed Pokémon with PokéDex Number 992
# Parsed Pokémon with PokéDex Number 993
# Parsed Pokémon with PokéDex Number 994
# Parsed Pokémon with PokéDex Number 995
# Parsed Pokémon with PokéDex Number 996
# Parsed Pokémon with PokéDex Number 997
# Parsed Pokémon with PokéDex Number 998
# Parsed Pokémon with PokéDex Number 999
# Parsed Pokémon with PokéDex Number 1000
# Parsed Pokémon with PokéDex Number 1001
# Parsed Pokémon with PokéDex Number 1002
# Parsed Pokémon with PokéDex Number 1003
# Parsed Pokémon with PokéDex Number 1004
# Parsed Pokémon with PokéDex Number 1005
# Parsed Pokémon with PokéDex Number 1006
# Parsed Pokémon with PokéDex Number 1007
# Parsed Pokémon with PokéDex Number 1008
# Parsed Pokémon with PokéDex Number 1009
# Parsed Pokémon with PokéDex Number 1010
# Parsed Pokémon with PokéDex Number 1011
# Parsed Pokémon with PokéDex Number 1012
# Parsed Pokémon with PokéDex Number 1013
# Parsed Pokémon with PokéDex Number 1014
# Parsed Pokémon with PokéDex Number 1015
# Parsed Pokémon with PokéDex Number 1016
# Parsed Pokémon with PokéDex Number 1017
# Parsed Pokémon with PokéDex Number 1018
# Parsed Pokémon with PokéDex Number 1019
# Parsed Pokémon with PokéDex Number 1020
# Parsed Pokémon with PokéDex Number 1021
# Parsed Pokémon with PokéDex Number 1022
# Parsed Pokémon with PokéDex Number 1023
# Parsed Pokémon with PokéDex Number 1024
# Parsed Pokémon with PokéDex Number 1025

# %%
# To show that the Pokémon has been correctly parsed and converted into a DataFrame, I will print the whole dataset as this
# will show me the shape of the DataFrame in addition to the first and last 5 observations.

all_pokemon
# Out:
#         id          name   hp  attack  defense  special_attack  \
# 0        1     bulbasaur   45      49       49              65
# 1        2       ivysaur   60      62       63              80
# 2        3      venusaur   80      82       83             100
# 3        4    charmander   39      52       43              60
# 4        5    charmeleon   58      64       58              80
# ...    ...           ...  ...     ...      ...             ...
# 1020  1021   raging-bolt  125      73       91             137
# 1021  1022  iron-boulder   90     120       80              68
# 1022  1023    iron-crown   90      72      100             122
# 1023  1024     terapagos   90      65       85              65
# 1024  1025     pecharunt   88      88      160              88
#
#       special_defense  speed primary_type secondary_type
# 0                  65     45        grass         poison
# 1                  80     60        grass         poison
# 2                 100     80        grass         poison
# 3                  50     65         fire           None
# 4                  65     80         fire           None
# ...               ...    ...          ...            ...
# 1020               89     75     electric         dragon
# 1021              108    124         rock        psychic
# 1022              108     98        steel        psychic
# 1023               85     60       normal           None
# 1024               88     88       poison          ghost
#
# [1025 rows x 10 columns]

# %% [markdown]
# ## Data Transformation 1: Replace Headers

# %%
# To match the headers of the two previous datasets that have been transformed for this term project, I will replace the 
# headers accordingly.

real_headers = ['Pokedex_entry_number', 'Pokemon_name', 'HP_stat', 'Attack_stat', 'Defense_stat', 'Special_attack_stat', 
                   'Special_defense_stat', 'Speed_stat', 'Primary_type', 'Secondary_type',]
all_pokemon.columns = real_headers

# The head() function is used simply to verify that the transformation of the data has been performed correctly.

all_pokemon.head()
# Out:
#    Pokedex_entry_number Pokemon_name  HP_stat  Attack_stat  Defense_stat  \
# 0                     1    bulbasaur       45           49            49
# 1                     2      ivysaur       60           62            63
# 2                     3     venusaur       80           82            83
# 3                     4   charmander       39           52            43
# 4                     5   charmeleon       58           64            58
#
#    Special_attack_stat  Special_defense_stat  Speed_stat Primary_type  \
# 0                   65                    65          45        grass
# 1                   80                    80          60        grass
# 2                  100                   100          80        grass
# 3                   60                    50          65         fire
# 4                   80                    65          80         fire
#
#   Secondary_type
# 0         poison
# 1         poison
# 2         poison
# 3           None
# 4           None

# %% [markdown]
# ## Data Transformation 2: Fill in Missing Values

# %%
# As we have seen in the dataset we worked with for the second milestone, the Pokémon who do not have a secondary type are 
# given a missing value. In this dataset, we have made that value appear as 'None'. Since 'None' is recognized as equal to 
# 'NaN', we can fill in these values using fillna(). I will be replacing the 'None' value with that Pokémon's primary type 
# so that both types will be the same for those who only have a primary type.

all_pokemon['Secondary_type'] = all_pokemon['Secondary_type'].fillna(all_pokemon['Primary_type'])

# The head() function is used simply to verify that the transformation of the data has been performed correctly.

all_pokemon.head()
# Out:
#    Pokedex_entry_number Pokemon_name  HP_stat  Attack_stat  Defense_stat  \
# 0                     1    bulbasaur       45           49            49
# 1                     2      ivysaur       60           62            63
# 2                     3     venusaur       80           82            83
# 3                     4   charmander       39           52            43
# 4                     5   charmeleon       58           64            58
#
#    Special_attack_stat  Special_defense_stat  Speed_stat Primary_type  \
# 0                   65                    65          45        grass
# 1                   80                    80          60        grass
# 2                  100                   100          80        grass
# 3                   60                    50          65         fire
# 4                   80                    65          80         fire
#
#   Secondary_type
# 0         poison
# 1         poison
# 2         poison
# 3           fire
# 4           fire

# %% [markdown]
# ## Data Transformation 3: Fix Letter Casing

# %%
# To make the dataset match the casing of my previous two datasets, I will fix the casing of the string observation dataset 
# columns so that the first letter of the data point is capitalized. This is accomplished using the str.title() function.

all_pokemon['Pokemon_name'] = all_pokemon['Pokemon_name'].str.title()
all_pokemon['Primary_type'] = all_pokemon['Primary_type'].str.title()
all_pokemon['Secondary_type'] = all_pokemon['Secondary_type'].str.title()

# The head() function is used simply to verify that the transformation of the data has been performed correctly.

all_pokemon.head()
# Out:
#    Pokedex_entry_number Pokemon_name  HP_stat  Attack_stat  Defense_stat  \
# 0                     1    Bulbasaur       45           49            49
# 1                     2      Ivysaur       60           62            63
# 2                     3     Venusaur       80           82            83
# 3                     4   Charmander       39           52            43
# 4                     5   Charmeleon       58           64            58
#
#    Special_attack_stat  Special_defense_stat  Speed_stat Primary_type  \
# 0                   65                    65          45        Grass
# 1                   80                    80          60        Grass
# 2                  100                   100          80        Grass
# 3                   60                    50          65         Fire
# 4                   80                    65          80         Fire
#
#   Secondary_type
# 0         Poison
# 1         Poison
# 2         Poison
# 3           Fire
# 4           Fire

# %% [markdown]
# ## Data Transformation 4: Remove Special Characters

# %%
# Looking back at the initial version of the dataset gathered and converted from the API data, the last few observations had
# dashes instead of spaces for some of the Pokémon names. I need to remove these dashes and replace them with spaces using 
# the str.replace() function.

all_pokemon['Pokemon_name'] = all_pokemon['Pokemon_name'].str.replace('-', ' ')

# The tail() function is used this time to verify that the transformation of the data has been performed correctly.

all_pokemon.tail()
# Out:
#       Pokedex_entry_number  Pokemon_name  HP_stat  Attack_stat  Defense_stat  \
# 1020                  1021   Raging Bolt      125           73            91
# 1021                  1022  Iron Boulder       90          120            80
# 1022                  1023    Iron Crown       90           72           100
# 1023                  1024     Terapagos       90           65            85
# 1024                  1025     Pecharunt       88           88           160
#
#       Special_attack_stat  Special_defense_stat  Speed_stat Primary_type  \
# 1020                  137                    89          75     Electric
# 1021                   68                   108         124         Rock
# 1022                  122                   108          98        Steel
# 1023                   65                    85          60       Normal
# 1024                   88                    88          88       Poison
#
#      Secondary_type
# 1020         Dragon
# 1021        Psychic
# 1022        Psychic
# 1023         Normal
# 1024          Ghost

# %% [markdown]
# ## Data Transformation 5: Add Useful Columns

# %%
# With this dataset being the most encompassing of the datasets I have worked with so far in this project, I wanted to add 
# the missing columns I saw in the last two datasets, which are the columns that denote the sum of the six Pokémon stats, 
# the average of these stats, and the standard deviation associated with the stats. Each column is created using these stats
# and thr sum() function, the mean(), and NumPy's std() function, respectively. I have imported NumPy here.

import numpy as np

all_pokemon['Total_stats'] = all_pokemon[['HP_stat', 'Attack_stat', 'Defense_stat', 'Special_attack_stat', 
                                          'Special_defense_stat', 'Speed_stat']].sum(axis=1)

# For the average and standard deviation, I chose to round off the answer to the nearest hundredth place with the 
# round() function with 2 as the argument.

all_pokemon['Avg_of_stats'] = all_pokemon[['HP_stat', 'Attack_stat', 'Defense_stat', 'Special_attack_stat', 
                                           'Special_defense_stat', 'Speed_stat']].mean(axis=1).round(2)

all_pokemon['Deviation_of_stats'] = np.std(all_pokemon[['HP_stat', 'Attack_stat', 'Defense_stat', 'Special_attack_stat', 
                                                 'Special_defense_stat', 'Speed_stat']], axis=1).round(2)

# The head() function is used simply to verify that the transformation of the data has been performed correctly.

all_pokemon.head()
# Out:
#    Pokedex_entry_number Pokemon_name  HP_stat  Attack_stat  Defense_stat  \
# 0                     1    Bulbasaur       45           49            49
# 1                     2      Ivysaur       60           62            63
# 2                     3     Venusaur       80           82            83
# 3                     4   Charmander       39           52            43
# 4                     5   Charmeleon       58           64            58
#
#    Special_attack_stat  Special_defense_stat  Speed_stat Primary_type  \
# 0                   65                    65          45        Grass
# 1                   80                    80          60        Grass
# 2                  100                   100          80        Grass
# 3                   60                    50          65         Fire
# 4                   80                    65          80         Fire
#
#   Secondary_type  Total_stats  Avg_of_stats  Deviation_of_stats
# 0         Poison          318          53.0                8.64
# 1         Poison          405          67.5                8.90
# 2         Poison          525          87.5                8.90
# 3           Fire          309          51.5                9.00
# 4           Fire          405          67.5                9.23

# %% [markdown]
# ## Ethical Implications

# %% [markdown]
# With the above changes made to the dataset (replacing headers, filling in missing values, fixing letter casing, removing special characters, and adding useful columns), I have arrived at a human-readable and clean dataset. As I have completed the transformation of the initial dataset parsed and converted from my chosen API URL to achieve the end result, I can see now that there are some ethical risks to consider when thinking about potential questions I might ask of the data. In the world of Pokémon, each creature is different, as is apparent with the display of various statistics attached to each observation. With this dataset, I feel that I have arrived at the best dataset to describe every Pokémon available to the public, save for any regional variants and Mega evolved Pokémon. With respect to the hypothetical question I have been asking of which Pokémon has the highest combined total stats, to mitigate the unintentional bias I have created towards Pokémon who are abnormal in the sense that they have different forms, I would have to reinclude both Pokémon with regional or other variants as well as Mega evolved Pokémon. The Pokémon API that was used here contains no data on these types of Pokémon, so I would have to look elsehwere to find data on the Pokémon I would need to add to the mix to truly figure out which one has the highest combined stat total. After excluding these Pokémon with each dataset, I will need to edit my prior question to something akin to "Which Pokémon (barring variant or unnatural evolution) has ther highest total combined stats?" This pivot to a revised question allows the natural removal of the aforementioned outlier Pokémon with no harm to the insight needed to answer the question at hand. Regarding the data itself, I am glad that I can manipulate the data freely with little to no worry of legal issues other than the fact that all of the observations within the dataset belong to the Pokémon Company, meaning that the data has been verified as accurate by the company itself and that it has been widely published for the public to have access to. In this case with the dataset being harvested from an API URL that represents the Pokémon Company through information found in the Pokémon games, they have accurately reported the data correctly. The API documentation also outlines its fair use policy, wrapper libraries, and other information that lets a user access the information held within the API URL in an ethically responsible way. Now that the dataset appropriately showcases the new features seen in the previous two milestones, I can now ethically expand on the question of which Pokémon has the highest combined stats by also inquiring which Pokémon has the highest average stats. This is considered an ethical approach as the new feature added (the average column) simply applies the arithmetic mean formula to the already verified Pokémon stats.
#
# While transforming the data from the API, I have assumed that each column of data would have the correct data type attached to it. I look forward to seeing if this is the case in the final milestone when I am to merge all three datasets together, as having integer types and object types trying to merge may not play out well if the data typing doesn't match up. Using the requests library in Python to acquire the data from my chosen API URL may bring up some ethical concerns, especially since some API calls are monitored for their use and can be limited to a specified number of calls per day. For my data however, as it is safely acquired for educational purposes and I have followed the fair use policy, the question of ethics is a moot point here. With the completion of this dataset, I am very much looking forward to merging the three finished datasets I have now crafted. The human-readable dataset I have cleaned and transformed is below.

# %%
all_pokemon.head(20)
# Out:
#     Pokedex_entry_number Pokemon_name  HP_stat  Attack_stat  Defense_stat  \
# 0                      1    Bulbasaur       45           49            49
# 1                      2      Ivysaur       60           62            63
# 2                      3     Venusaur       80           82            83
# 3                      4   Charmander       39           52            43
# 4                      5   Charmeleon       58           64            58
# 5                      6    Charizard       78           84            78
# 6                      7     Squirtle       44           48            65
# 7                      8    Wartortle       59           63            80
# 8                      9    Blastoise       79           83           100
# 9                     10     Caterpie       45           30            35
# 10                    11      Metapod       50           20            55
# 11                    12   Butterfree       60           45            50
# 12                    13       Weedle       40           35            30
# 13                    14       Kakuna       45           25            50
# 14                    15     Beedrill       65           90            40
# 15                    16       Pidgey       40           45            40
# 16                    17    Pidgeotto       63           60            55
# 17                    18      Pidgeot       83           80            75
# 18                    19      Rattata       30           56            35
# 19                    20     Raticate       55           81            60
#
#     Special_attack_stat  Special_defense_stat  Speed_stat Primary_type  \
# 0                    65                    65          45        Grass
# 1                    80                    80          60        Grass
# 2                   100                   100          80        Grass
# 3                    60                    50          65         Fire
# 4                    80                    65          80         Fire
# 5                   109                    85         100         Fire
# 6                    50                    64          43        Water
# 7                    65                    80          58        Water
# 8                    85                   105          78        Water
# 9                    20                    20          45          Bug
# 10                   25                    25          30          Bug
# 11                   90                    80          70          Bug
# 12                   20                    20          50          Bug
# 13                   25                    25          35          Bug
# 14                   45                    80          75          Bug
# 15                   35                    35          56       Normal
# 16                   50                    50          71       Normal
# 17                   70                    70         101       Normal
# 18                   25                    35          72       Normal
# 19                   50                    70          97       Normal
#
#    Secondary_type  Total_stats  Avg_of_stats  Deviation_of_stats
# 0          Poison          318         53.00                8.64
# 1          Poison          405         67.50                8.90
# 2          Poison          525         87.50                8.90
# 3            Fire          309         51.50                9.00
# 4            Fire          405         67.50                9.23
# 5          Flying          534         89.00               11.58
# 6           Water          314         52.33                8.92
# 7           Water          405         67.50                9.14
# 8           Water          530         88.33               10.39
# 9             Bug          195         32.50               10.31
# 10            Bug          205         34.17               13.36
# 11         Flying          395         65.83               15.92
# 12         Poison          195         32.50               10.70
# 13         Poison          205         34.17               10.17
# 14         Poison          395         65.83               18.12
# 15         Flying          251         41.83                7.20
# 16         Flying          349         58.17                7.47
# 17         Flying          479         79.83               10.61
# 18         Normal          253         42.17               16.47
# 19         Normal          413         68.83               16.16
